# %%
# !pip install -U langgraph
# Out:
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached uuid_utils-0.14.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.9 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# ...
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# ...
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/1.9 MB 70.0 kB/s eta 0:00:20
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (524 kB/1.9 MB, attempt 1)
# Resuming download pydantic_core-2.41.5-cp314-cp314-macosx_11_0_arm64.whl (524 kB/1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 328.9 kB/s  0:00:04 eta 0:00:01
# ...

# %%
from langgraph.graph import StateGraph
# Out:
# /Users/consultadd/Downloads/langgraph-tutorials-main/Sequential Workflow/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
