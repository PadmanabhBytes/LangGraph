# %%
# !pip install -U langgraph
# Out:
# /Users/consultadd/Downloads/langgraph-tutorials-main/LangGraph/.venv/bin/pip: line 2: /Users/consultadd/Downloads/langgraph-tutorials-main/Sequential Workflow/.venv/bin/python3.14: No such file or directory
# /Users/consultadd/Downloads/langgraph-tutorials-main/LangGraph/.venv/bin/pip: line 2: exec: /Users/consultadd/Downloads/langgraph-tutorials-main/Sequential Workflow/.venv/bin/python3.14: cannot execute: No such file or directory

# %%
from langgraph.graph import StateGraph
# Out:
# /Users/consultadd/Downloads/langgraph-tutorials-main/LangGraph/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
